# %%
import os
import yaml
import pandas as pd

ROOT_DIR = "/home/melodino/veh_type_pred"

# %%
def load_yaml(file_path):
    """Load a YAML file and return the content."""
    with open(file_path, 'r') as file:
        return yaml.safe_load(file)

def parse_dependencies(dependencies):
    """Parse the list of dependencies into a dictionary of package, version, and build."""
    dep_dict = {}
    for dep in dependencies:
        if isinstance(dep, str):
            parts = dep.split('=')
            if len(parts) == 3:
                package, version, build = parts
                dep_dict[package] = {'version': version, 'build': build}
            elif len(parts) == 2:
                package, version = parts
                dep_dict[package] = {'version': version, 'build': None}
            else:
                dep_dict[package] = {'version': None, 'build': None}  # No version or build specified
        elif isinstance(dep, dict):
            pip_packages = dep['pip']
            for pip_pkg in pip_packages:
                package, version = pip_pkg.split('==')
                dep_dict[package] = {'version': version, 'build': 'pip'}
    return dep_dict


def compare_envs(env1, env2):
    """Compare the dependencies of two environments."""
    dep1 = parse_dependencies(env1.get('dependencies', []))
    dep2 = parse_dependencies(env2.get('dependencies', []))
    
    all_keys = set(dep1.keys()).union(set(dep2.keys()))
    data = []

    for key in all_keys:
        env1_info = dep1.get(key, {'version': 'non_existent', 'build': 'non_existent'})
        env2_info = dep2.get(key, {'version': 'non_existent', 'build': 'non_existent'})

        # Add to data only if builds are different or the package exists in only one environment
        if env1_info['build'] != env2_info['build'] or env1_info['version'] == 'non_existent' or env2_info['version'] == 'non_existent':
            data.append([
                key,
                env1_info['version'],
                env1_info['build'],
                env2_info['version'],
                env2_info['build']
            ])
    
    # Create a DataFrame from the collected data
    df = pd.DataFrame(data, columns=['Package', 'Env1_Version', 'Env1_Build', 'Env2_Version', 'Env2_Build'])
    return df

# %%
# Load the environments
env1 = load_yaml(f"{ROOT_DIR}/target_env.yml")
env2 = load_yaml(f"{ROOT_DIR}/env.yml")

# Compare environments and generate DataFrame
comparison_df = compare_envs(env1, env2)
comparison_df.sort_values(by=['Package'], inplace=True)

# Print the DataFrame
with pd.option_context('display.max_rows', None):  # Sets max_rows to None within the block
    display(comparison_df)
# Out:
#                            Package         Env1_Version  \
# 152              _anaconda_depends              2024.02
# 359                  _libgcc_mutex         non_existent
# 545                  _openmp_mutex         non_existent
# 312                     abseil-cpp           20220623.0
# 408                        absl-py         non_existent
# 159                    aiobotocore                2.7.0
# 325                        aiohttp                3.9.3
# 35                    aiohttp-cors                0.7.0
# 584                   aioitertools                0.7.1
# 589                      aiosignal                1.2.0
# 540                      alabaster               0.7.12
# 138                        alembic               1.13.1
# 682                       alsa-lib         non_existent
# 605                         altair                5.0.1
# 281            anaconda-anon-usage                0.4.3
# 472              anaconda-catalogs                0.2.0
# 77                 anaconda-client               1.12.3
# 402            anaconda-cloud-auth                0.1.4
# 516             anaconda-navigator                2.5.2
# 121               anaconda-project               0.11.1
# 304                        ansicon               1.89.0
# 463                          anyio                4.2.0
# 423                            aom                3.6.0
# 671                        appdirs                1.4.4
# 269                       archspec                0.2.3
# 228                    argon2-cffi               21.3.0
# 277           argon2-cffi-bindings               21.2.0
# 248                          arrow                1.2.3
# 254                      arrow-cpp               11.0.0
# 271                        astroid               2.14.2
# 60                         astropy                5.3.4
# 686                      asttokens                2.0.5
# 595                      async-lru                2.0.4
# 703                  async-timeout                4.0.3
# 496                   atomicwrites                1.4.0
# 631                           attr         non_existent
# 525                          attrs               23.1.0
# 194                        automat               20.2.0
# 198                       autopep8                1.6.0
# 67                      aws-c-auth                0.7.4
# 324                      aws-c-cal                0.6.2
# 123                   aws-c-common                0.9.3
# 136              aws-c-compression               0.2.17
# 430             aws-c-event-stream                0.3.2
# 342                     aws-c-http               0.7.13
# 72                        aws-c-io              0.13.33
# 470                     aws-c-mqtt                0.9.7
# 140                       aws-c-s3               0.3.17
# 298                 aws-c-sdkutils               0.1.12
# 543                  aws-checksums               0.1.17
# 151                    aws-crt-cpp               0.24.2
# 61                     aws-sdk-cpp              1.10.57
# 457                          babel               2.11.0
# 331                      backports                  1.1
# 223  backports.functools_lru_cache                1.6.4
# 0               backports.tempfile                  1.0
# 695              backports.weakref            1.0.post1
# 339          bayesian-optimization                1.4.3
# 435                         bcrypt                3.2.0
# 663                 beautifulsoup4               4.12.2
# 86                     binaryornot                0.4.4
# 222                          black              23.11.0
# 231                         bleach                4.1.0
# 624                        blessed               1.19.1
# 262                        blinker                1.6.2
# 552                          blosc               1.21.3
# 600                          bokeh                3.3.4
# 226                        boltons               23.0.0
# 433                      boost-cpp               1.82.0
# 79                        botocore              1.31.64
# 249                     bottleneck                1.3.7
# 370                         brotli                1.0.9
# 334                     brotli-bin                1.0.9
# 80                   brotli-python                1.0.9
# 62                           bzip2                1.0.8
# 664                         c-ares               1.19.1
# 547                       c-blosc2               2.12.0
# 494                ca-certificates            2024.3.11
# 667                cached-property         non_existent
# 702                cached_property         non_existent
# 208                     cachetools                4.2.2
# 286                          cairo         non_existent
# 70                            cffi               1.16.0
# 529                        cfitsio                3.470
# 368                        chardet                4.0.0
# 257                         charls                2.2.0
# 188             charset-normalizer                2.0.4
# 554                          click                8.1.7
# 700                    cloudpickle                2.2.1
# 189                         clyent                1.2.2
# 95                           cmake         non_existent
# 315                       colorama                0.4.6
# 78                        colorcet                3.0.1
# 141                       colorful                0.5.6
# 32                        colorlog                6.8.2
# 37                            comm                0.1.2
# 147                          conda               24.3.0
# 647                    conda-build               24.1.2
# 329            conda-content-trust                0.2.0
# 593                    conda-index                0.4.0
# 594          conda-libmamba-solver               24.1.0
# 421                     conda-pack                0.6.0
# 488         conda-package-handling                2.2.0
# 328        conda-package-streaming                0.9.0
# 626                 conda-repo-cli               1.0.75
# 202                    conda-token                0.4.0
# 422                   conda-verify                3.4.2
# 199               console_shortcut                0.1.1
# 100                     constantly              23.10.4
# 618                      contourpy                1.2.0
# 163                   cookiecutter                2.5.0
# 507                        cpuonly         non_existent
# 103                   cryptography               42.0.2
# 150                      cssselect                1.2.0
# 235                      cuda-cccl             12.4.127
# 48                     cuda-cudart             12.1.105
# 309                cuda-cudart-dev             12.1.105
# 153                     cuda-cupti             12.1.105
# 518                 cuda-libraries               12.1.0
# 638             cuda-libraries-dev               12.1.0
# 261                     cuda-nvrtc             12.1.105
# 706                 cuda-nvrtc-dev             12.1.105
# 684                      cuda-nvtx             12.1.105
# 617                    cuda-opencl             12.4.127
# 26                 cuda-opencl-dev             12.4.127
# 274              cuda-profiler-api             12.4.127
# 88                    cuda-runtime               12.1.0
# 114                           curl                8.5.0
# 379                         cycler               0.11.0
# 111                        cytoolz               0.12.2
# 224                           dask            2023.11.0
# 18                       dask-core            2023.11.0
# 565                     datashader               0.16.0
# 168                          dav1d                1.2.1
# 115                           dbus         non_existent
# 563                        debugpy                1.6.7
# 317                      decorator                5.1.1
# 523                     defusedxml                0.7.1
# 403               diff-match-patch             20200713
# 544                           dill                0.3.7
# 482                        distlib                0.3.8
# 569                    distributed            2023.11.0
# 6                           distro                1.8.0
# 355          docstring-to-markdown                 0.11
# 270                       docutils               0.18.1
# 555                    entrypoints                  0.4
# 83                      et_xmlfile                1.1.0
# 244                 exceptiongroup         non_existent
# 335                      executing                0.8.3
# 697                          expat         non_existent
# 85                        filelock               3.13.1
# 87                          flake8                6.0.0
# 431                          flask                2.2.5
# 522                            fmt                9.1.0
# 630      font-ttf-dejavu-sans-mono         non_existent
# 448           font-ttf-inconsolata         non_existent
# 381       font-ttf-source-code-pro         non_existent
# 84                 font-ttf-ubuntu         non_existent
# 369                     fontconfig         non_existent
# 484          fonts-conda-ecosystem         non_existent
# 539              fonts-conda-forge         non_existent
# 505                      fonttools               4.25.0
# 383                       freetype               2.12.1
# 551                     frozenlist                1.4.0
# 10                          fsspec            2023.10.0
# 459                         future               0.18.3
# 675                         gensim                4.3.0
# 110                        gettext         non_existent
# 632                  gettext-tools         non_existent
# 204                         gflags                2.2.2
# 306                         giflib                5.2.1
# 635                          gitdb                4.0.7
# 318                      gitpython               3.1.37
# 519                           glib         non_existent
# 214                     glib-tools         non_existent
# 319                           glog                0.6.0
# 627                            gmp         non_existent
# 22                           gmpy2                2.1.2
# 172                google-api-core               2.18.0
# 296                    google-auth               2.29.0
# 574       googleapis-common-protos               1.63.0
# 444                        gpustat                1.1.1
# 378                      graphite2         non_existent
# 394                       greenlet                3.0.1
# 382                       grpc-cpp               1.51.1
# 250                         grpcio               1.51.1
# 681               gst-plugins-base         non_existent
# 704                      gstreamer         non_existent
# 596                           h5py                3.9.0
# 161                       harfbuzz         non_existent
# 213                           hdf5               1.12.1
# 566                       heapdict                1.0.1
# 160                      holoviews               1.18.3
# 130                         hvplot                0.9.2
# 358                      hyperlink               21.0.0
# 465                         icc_rt             2022.1.0
# 53                             icu                 73.1
# 655                           idna                  3.4
# 508                    imagecodecs            2023.1.23
# 560                        imageio               2.33.1
# 39                       imagesize                1.4.1
# 246               imbalanced-learn               0.11.0
# 393             importlib-metadata                7.0.1
# 674             importlib_metadata                7.0.1
# 441            importlib_resources                6.4.0
# 442                    incremental              22.10.0
# 337                     inflection                0.5.1
# 604                      iniconfig                1.1.1
# 195                         intake                0.6.8
# 104                   intel-openmp             2023.1.0
# 698                   intervaltree                3.1.0
# 89                       ipykernel               6.28.0
# 343                        ipython               8.20.0
# 126               ipython_genutils                0.2.0
# 677                     ipywidgets                7.6.5
# 9                            isort                5.9.3
# 116                    itemadapter                0.3.0
# 420                    itemloaders                1.1.0
# 183                   itsdangerous                2.0.1
# 162                 jaraco.classes                3.2.1
# 36                            jedi               0.18.1
# 293                      jellyfish                1.0.1
# 490                         jinja2                3.1.3
# 607                         jinxed                1.2.1
# 273                       jmespath                1.0.1
# 651                         joblib                1.2.0
# 81                            jpeg                   9e
# 511                             jq                  1.6
# 71                           json5                0.9.6
# 34                       jsonpatch                 1.32
# 14                     jsonpointer                  2.1
# 142                     jsonschema               4.19.2
# 533      jsonschema-specifications             2023.7.1
# 445                        jupyter                1.0.0
# 460                    jupyter-lsp                2.2.0
# 330                 jupyter_client                8.6.0
# 672                jupyter_console                6.6.3
# 57                    jupyter_core                5.5.0
# 687                 jupyter_events                0.8.0
# 332                 jupyter_server               2.10.0
# 303       jupyter_server_terminals                0.4.4
# 376                     jupyterlab               4.0.11
# 461   jupyterlab-variableinspector                3.1.0
# 653            jupyterlab_pygments                0.1.2
# 646              jupyterlab_server               2.25.1
# 497             jupyterlab_widgets                3.0.9
# 679                        keyring              23.13.1
# 406                       keyutils         non_existent
# 365                     kiwisolver                1.4.4
# 588                           krb5               1.20.1
# 69                            lame         non_existent
# 63               lazy-object-proxy                1.6.0
# 238                    lazy_loader                  0.3
# 356                          lcms2                 2.12
# 666               ld_impl_linux-64         non_existent
# 135                           lerc                  3.0
# 206                      libabseil           20220623.0
# 528                         libaec                1.0.4
# 361                     libarchive                3.6.2
# 530                       libarrow               11.0.0
# 615                    libasprintf         non_existent
# 520              libasprintf-devel         non_existent
# 587                        libavif               0.11.1
# 462                        libblas                3.9.0
# 292                       libboost               1.82.0
# 207                libbrotlicommon                1.0.9
# 354                   libbrotlidec                1.0.9
# 284                   libbrotlienc                1.0.9
# 375                         libcap         non_existent
# 636                       libcblas                3.9.0
# 285                       libclang               14.0.6
# 417                 libclang-cpp15         non_existent
# 247                     libclang13               14.0.6
# 23                       libcrc32c                1.1.2
# 267                      libcublas            12.1.0.26
# 366                  libcublas-dev            12.1.0.26
# 109                       libcufft             11.0.2.4
# 280                   libcufft-dev             11.0.2.4
# 510                        libcups         non_existent
# 500                      libcurand           10.3.5.147
# 68                   libcurand-dev           10.3.5.147
# 592                        libcurl                8.5.0
# 233                    libcusolver            11.4.4.55
# 650                libcusolver-dev            11.4.4.55
# 373                    libcusparse            12.0.2.55
# 673                libcusparse-dev            12.0.2.55
# 217                     libdeflate                 1.17
# 12                         libedit         non_existent
# 553                          libev         non_existent
# 524                       libevent               2.1.12
# 139                       libexpat         non_existent
# 58                          libffi                3.4.4
# 513                        libflac         non_existent
# 276                      libgcc-ng         non_existent
# 591                      libgcrypt         non_existent
# 137                   libgettextpo         non_existent
# 669             libgettextpo-devel         non_existent
# 236                 libgfortran-ng         non_existent
# 256                   libgfortran5         non_existent
# 174                        libglib         non_existent
# 612                        libgomp         non_existent
# 122                libgoogle-cloud                2.7.0
# 237                   libgpg-error         non_existent
# 660                        libgrpc               1.51.1
# 283                       libiconv                 1.16
# 259                  libjpeg-turbo                2.0.0
# 546                      liblapack                3.9.0
# 377                        liblief               0.12.3
# 297                      libllvm14         non_existent
# 200                      libllvm15         non_existent
# 401                      libllvm18         non_existent
# 654                       libmamba                1.5.6
# 699                     libmambapy                1.5.6
# 425                     libnghttp2         non_existent
# 556                         libnpp            12.0.2.50
# 295                     libnpp-dev            12.0.2.50
# 532                         libnsl         non_existent
# 15                    libnvjitlink             12.1.105
# 434               libnvjitlink-dev             12.1.105
# 455                      libnvjpeg            12.1.1.14
# 685                  libnvjpeg-dev            12.1.1.14
# 279                         libogg         non_existent
# 311                    libopenblas         non_existent
# 487                        libopus         non_existent
# 515                         libpng               1.6.39
# 154                          libpq                12.17
# 38                     libprotobuf              3.21.12
# 117                      libre2-11         non_existent
# 75                      libsndfile         non_existent
# 291                      libsodium               1.0.18
# 404                        libsolv               0.7.24
# 108                libspatialindex                1.9.3
# 336                      libsqlite         non_existent
# 517                        libssh2               1.10.0
# 579                   libstdcxx-ng         non_existent
# 349                    libsystemd0         non_existent
# 610                      libthrift               0.18.0
# 255                        libtiff                4.5.1
# 260                    libutf8proc                2.8.0
# 91                         libuuid         non_existent
# 333                          libuv               1.44.2
# 158                      libvorbis         non_existent
# 619                   libwebp-base                1.3.2
# 197                         libxcb         non_existent
# 242                      libxcrypt         non_existent
# 31                    libxkbcommon         non_existent
# 597                        libxml2               2.10.4
# 16                         libxslt               1.1.37
# 229                        libzlib               1.2.13
# 628                      libzopfli                1.0.3
# 447                      lightning                2.2.2
# 1              lightning-utilities               0.11.2
# 372                  linkify-it-py                2.0.0
# 656                            lit         non_existent
# 380                    llvm-openmp         non_existent
# 167                       llvmlite               0.42.0
# 55                          locket                1.0.0
# 243                           lxml                4.9.3
# 659                            lz4                4.3.2
# 157                          lz4-c                1.9.4
# 362                            lzo                 2.10
# 481               m2-msys2-runtime  2.5.0.17080.65c939c
# 302                       m2-patch                2.7.5
# 601        m2w64-libwinpthread-git   5.0.0.4634.697f757
# 384                           mako                1.3.3
# 165                       markdown                3.4.1
# 585                 markdown-it-py                2.2.0
# 397                     markupsafe                2.1.3
# 52                      matplotlib                3.8.0
# 550                matplotlib-base                3.8.0
# 350              matplotlib-inline                0.1.6
# 251                         mccabe                0.7.0
# 25                 mdit-py-plugins                0.3.0
# 643                          mdurl                0.1.0
# 485                       menuinst                2.0.2
# 538                        mistune                2.0.4
# 102                            mkl             2021.4.0
# 316                    mkl-service                2.4.0
# 179                        mkl_fft                1.3.1
# 559                     mkl_random                1.2.2
# 701                 more-itertools               10.1.0
# 456                            mpc                1.1.0
# 107                           mpfr                4.0.2
# 690                         mpg123         non_existent
# 571                           mpir                3.0.0
# 693                         mpmath                1.3.0
# 97                  msgpack-python                1.0.3
# 210              msys2-conda-epoch             20160418
# 11                       multidict                6.0.4
# 599               multipledispatch                0.6.0
# 93                         munkres                1.1.4
# 143                           mypy                1.8.0
# 680                mypy_extensions                1.0.0
# 59                    mysql-common         non_existent
# 645                     mysql-libs         non_existent
# 410              navigator-updater                0.4.0
# 583                       nbclient                0.8.0
# 407                      nbconvert               7.10.0
# 580                       nbformat                5.9.2
# 509                        ncurses         non_existent
# 582                   nest-asyncio                1.6.0
# 186                       networkx                  3.1
# 56                            nltk                3.8.1
# 598                         nodejs              18.19.0
# 452                       notebook                7.0.8
# 239                  notebook-shim                0.2.3
# 301                           nspr         non_existent
# 166                            nss         non_existent
# 230                          numba               0.59.0
# 424                        numexpr                2.8.4
# 169                          numpy               1.24.3
# 265                     numpy-base               1.24.3
# 173                       numpydoc                1.5.0
# 549             nvidia-cublas-cu11         non_existent
# 678             nvidia-cublas-cu12         non_existent
# 411         nvidia-cuda-cupti-cu11         non_existent
# 346         nvidia-cuda-cupti-cu12         non_existent
# 348         nvidia-cuda-nvrtc-cu11         non_existent
# 665         nvidia-cuda-nvrtc-cu12         non_existent
# 642       nvidia-cuda-runtime-cu11         non_existent
# 662       nvidia-cuda-runtime-cu12         non_existent
# 219              nvidia-cudnn-cu11         non_existent
# 390              nvidia-cudnn-cu12         non_existent
# 634              nvidia-cufft-cu11         non_existent
# 413              nvidia-cufft-cu12         non_existent
# 205             nvidia-curand-cu11         non_existent
# 489             nvidia-curand-cu12         non_existent
# 3             nvidia-cusolver-cu11         non_existent
# 19            nvidia-cusolver-cu12         non_existent
# 371           nvidia-cusparse-cu11         non_existent
# 129           nvidia-cusparse-cu12         non_existent
# 415                   nvidia-ml-py           12.535.133
# 113               nvidia-nccl-cu11         non_existent
# 474               nvidia-nccl-cu12         non_existent
# 573          nvidia-nvjitlink-cu12         non_existent
# 275               nvidia-nvtx-cu11         non_existent
# 633               nvidia-nvtx-cu12         non_existent
# 352                     opencensus               0.11.3
# 17              opencensus-context                0.1.3
# 418                  opencv-python         non_existent
# 453                       openjpeg                2.4.0
# 412                       openpyxl               3.0.10
# 590                        openssl                3.2.1
# 263                         optuna                3.6.0
# 558                            orc                1.8.2
# 182                      overrides                7.4.0
# 439                      packaging                 23.1
# 689                         pandas                2.1.4
# 106                  pandocfilters                1.5.0
# 478                          panel                1.3.8
# 449                          param                2.0.2
# 176                       paramiko                2.8.1
# 616                    parquet-cpp                1.5.1
# 621                         parsel                1.8.1
# 385                          parso                0.8.3
# 203                          partd                1.4.1
# 131                        pathlib                1.0.1
# 364                       pathspec               0.10.3
# 648                          patsy                0.5.3
# 641                          pcre2                10.42
# 611                        pexpect                4.8.0
# 466                    pickleshare                0.7.5
# 76                          pillow               10.2.0
# 432                            pip               23.3.1
# 688                         pixman         non_existent
# 29                            pkce                1.0.3
# 294                        pkginfo                1.9.6
# 658                   platformdirs               3.10.0
# 504                         plotly                5.9.0
# 477                         pluggy                1.0.0
# 640                            ply                 3.11
# 541            powershell_shortcut                0.0.1
# 218              prometheus_client               0.14.1
# 367                 prompt-toolkit               3.0.43
# 416                 prompt_toolkit               3.0.43
# 225                        protego               0.1.16
# 132                     proto-plus               1.23.0
# 427                       protobuf              4.21.12
# 564                         psutil                5.9.0
# 44                   pthread-stubs         non_existent
# 234                     ptyprocess                0.7.0
# 178              pulseaudio-client         non_existent
# 392                      pure_eval                0.2.2
# 399                     py-cpuinfo                9.0.0
# 313                        py-lief               0.12.3
# 652                         py-spy               0.3.14
# 305                        pyarrow               11.0.0
# 20                          pyasn1                0.4.8
# 164                 pyasn1-modules                0.2.8
# 705                   pybind11-abi                    4
# 428                    pycodestyle               2.10.0
# 327                        pycosat                0.6.6
# 446                      pycparser                 2.21
# 475                           pyct                0.5.0
# 177                         pycurl               7.45.2
# 649                       pydantic              1.10.12
# 272                         pydeck                0.8.0
# 209                   pydispatcher                2.0.5
# 458                     pydocstyle                6.3.0
# 499                         pyerfa                2.0.0
# 127                       pyflakes                3.0.1
# 145                       pygments               2.15.1
# 576                          pyjwt                2.4.0
# 341                         pylint               2.16.2
# 586                    pylint-venv                2.3.0
# 128                    pyls-spyder                0.4.0
# 252                         pynacl                1.5.0
# 670                         pyodbc                5.0.1
# 278                      pyopenssl               24.0.0
# 90                       pyparsing                3.0.9
# 41                            pyqt              5.15.10
# 575                      pyqt5-sip              12.13.0
# 625                  pyqtwebengine              5.15.10
# 360                        pysocks                1.7.1
# 184                       pytables                3.9.2
# 577                         pytest                7.4.0
# 391                         python               3.11.7
# 42                 python-dateutil                2.8.2
# 613                  python-dotenv               0.21.0
# 429          python-fastjsonschema               2.16.2
# 307             python-json-logger                2.0.7
# 542            python-libarchive-c                  2.9
# 7                      python-lmdb                1.4.1
# 232               python-lsp-black                1.2.1
# 24              python-lsp-jsonrpc                1.0.0
# 170              python-lsp-server                1.7.2
# 637                 python-slugify                5.0.2
# 450                  python-snappy                0.6.1
# 495                  python-tzdata               2023.3
# 54                      python_abi                 3.11
# 221                   pytoolconfig                1.2.6
# 118                        pytorch                2.3.0
# 534                   pytorch-cuda                 12.1
# 614              pytorch-lightning                2.2.2
# 526                  pytorch-mutex                  1.0
# 676                           pytz         2023.3.post1
# 692                          pyu2f                0.1.5
# 400                    pyviz_comms                3.0.0
# 363                     pywavelets                1.5.0
# 30                         pywin32                  305
# 181                 pywin32-ctypes                0.2.0
# 344                       pywinpty               2.0.10
# 175                         pyyaml                6.0.1
# 266                          pyzmq               25.1.2
# 124                     qdarkstyle                3.0.2
# 480                      qstylizer                0.2.2
# 644                        qt-main               5.15.2
# 216                   qt-webengine               5.15.9
# 74                       qtawesome                1.2.2
# 603                      qtconsole                5.4.2
# 471                           qtpy                2.4.1
# 212                       queuelib                1.6.2
# 340                       ray-core                2.8.1
# 149                    ray-default                2.8.1
# 426                      ray-train                2.8.1
# 639                       ray-tune                2.8.1
# 148                            re2           2023.02.01
# 357                       readline         non_existent
# 374                    referencing               0.30.2
# 419                          regex            2023.10.3
# 514                         reproc               14.2.4
# 314                     reproc-cpp               14.2.4
# 438                       requests               2.31.0
# 572                  requests-file                1.5.1
# 609              requests-toolbelt                1.0.0
# 300              rfc3339-validator                0.1.4
# 101              rfc3986-validator                0.1.1
# 13                            rich               13.3.5
# 47                            rope                1.7.0
# 386                        rpds-py               0.10.6
# 562                            rsa                  4.9
# 661                          rtree                1.0.1
# 691                    ruamel.yaml              0.17.21
# 64                     ruamel_yaml              0.17.21
# 629                           s3fs            2023.10.0
# 211                   scikit-image               0.22.0
# 467                   scikit-learn                1.2.2
# 668                          scipy               1.13.0
# 288                         scrapy                2.8.0
# 27                         seaborn               0.12.2
# 310                   seaborn-base         non_existent
# 491                         semver               2.13.0
# 347                     send2trash                1.8.2
# 501               service_identity               18.1.0
# 94                    setproctitle                1.3.3
# 258                     setuptools               68.2.2
# 245                            sip               6.7.12
# 299                            six               1.16.0
# 322                     smart_open                5.2.1
# 506                          smmap                4.0.0
# 557                         snappy               1.1.10
# 387                        sniffio                1.3.0
# 502                snowballstemmer                2.2.0
# 264               sortedcontainers                2.4.0
# 133                      soupsieve                  2.5
# 98                          sphinx                5.0.2
# 290        sphinxcontrib-applehelp                1.0.2
# 476          sphinxcontrib-devhelp                1.0.2
# 527         sphinxcontrib-htmlhelp                2.0.0
# 581           sphinxcontrib-jsmath                1.0.1
# 215           sphinxcontrib-qthelp                1.0.3
# 220  sphinxcontrib-serializinghtml                1.1.5
# 440                         spyder                5.4.3
# 171                 spyder-kernels                2.4.4
# 454                     sqlalchemy               2.0.25
# 468                         sqlite               3.41.2
# 326                     stack_data                0.2.0
# 623                    statsmodels               0.14.0
# 144                      streamlit               1.30.0
# 620                          sympy                 1.12
# 345                       tabulate                0.9.0
# 606                            tbb             2021.8.0
# 388                          tblib                1.7.0
# 320                       tenacity                8.2.2
# 21                     tensorboard         non_existent
# 282        tensorboard-data-server         non_existent
# 40                    tensorboardx              2.6.2.2
# 602                      terminado               0.17.1
# 33                  text-unidecode                  1.3
# 479                   textdistance                4.2.1
# 578                  threadpoolctl                2.2.0
# 321                    three-merge                0.1.1
# 608                       tifffile            2023.4.12
# 548                       tinycss2                1.2.1
# 92                              tk               8.6.12
# 28                      tldextract                3.2.0
# 622                           toml               0.10.2
# 96                           tomli         non_existent
# 567                        tomlkit               0.11.1
# 405                          toolz               0.12.0
# 45                           torch         non_existent
# 395                 torch-directml         non_existent
# 8                       torchaudio                2.3.0
# 65                    torchmetrics                1.3.2
# 486                        tornado                6.3.3
# 99                            tqdm               4.65.0
# 193                      traitlets                5.7.1
# 561                         triton         non_existent
# 134                     truststore                0.8.0
# 437                        tslearn                0.6.3
# 119                        twisted              23.10.0
# 146            twisted-iocpsupport                1.0.2
# 570              typing-extensions                4.9.0
# 696              typing_extensions                4.9.0
# 464                         tzdata                2023d
# 156                        tzlocal                  2.1
# 46                     uc-micro-py                1.0.1
# 531                           ucrt         10.0.22621.0
# 568                          ujson                5.4.0
# 308                   unicodedata2         non_existent
# 694                      unidecode                1.2.0
# 180                        urllib3                2.0.7
# 227                       utf8proc                2.6.1
# 396                     validators               0.18.2
# 268                             vc                 14.2
# 120                   vc14_runtime          14.38.33130
# 105                     virtualenv              20.21.0
# 492                 vs2015_runtime          14.38.33130
# 443                          w3lib                2.1.2
# 537                       watchdog                2.1.6
# 521                        wcwidth                0.2.5
# 43                    webencodings                0.5.1
# 112               websocket-client               0.58.0
# 287                       werkzeug                2.2.3
# 436                           wget         non_existent
# 50                    whatthepatch                1.0.2
# 323                          wheel               0.41.2
# 289             widgetsnbextension                3.5.2
# 66                   win_inet_pton                1.1.0
# 192                         winpty                0.4.3
# 2                            wrapt               1.14.1
# 4                           xarray             2023.6.0
# 185                       xcb-util         non_existent
# 73                  xcb-util-image         non_existent
# 82                xcb-util-keysyms         non_existent
# 338            xcb-util-renderutil         non_existent
# 409                    xcb-util-wm         non_existent
# 536               xkeyboard-config         non_existent
# 498                        xlwings               0.29.1
# 125                   xorg-kbproto         non_existent
# 196                    xorg-libice         non_existent
# 657                     xorg-libsm         non_existent
# 351                    xorg-libx11         non_existent
# 389                    xorg-libxau         non_existent
# 201                  xorg-libxdmcp         non_existent
# 51                    xorg-libxext         non_existent
# 253                xorg-libxrender         non_existent
# 190               xorg-renderproto         non_existent
# 240                 xorg-xextproto         non_existent
# 5            xorg-xf86vidmodeproto         non_existent
# 353                    xorg-xproto         non_existent
# 155                    xyzservices             2022.9.0
# 493                             xz                5.4.5
# 483                           yaml                0.2.5
# 683                       yaml-cpp                0.8.0
# 414                           yapf               0.31.0
# 535                           yarl                1.9.3
# 512                         zeromq                4.3.5
# 503                            zfp                1.0.0
# 451                           zict                3.0.0
# 49                            zipp               3.17.0
# 241                           zlib               1.2.13
# 187                        zlib-ng                2.0.7
# 191                           zope                  1.0
# 469                 zope.interface                5.4.0
# 398                      zstandard               0.19.0
# 473                           zstd                1.5.5
#
#                    Env1_Build     Env2_Version               Env2_Build
# 152               py311_mkl_1     non_existent             non_existent
# 359              non_existent              0.1              conda_forge
# 545              non_existent              4.5                    2_gnu
# 312                h0e60522_0     non_existent             non_existent
# 408              non_existent            2.1.0             pyhd8ed1ab_0
# 159           py311haa95532_0     non_existent             non_existent
# 325           py311h2bbff1b_0     non_existent             non_existent
# 35                       py_0     non_existent             non_existent
# 584              pyhd3eb1b0_0     non_existent             non_existent
# 589              pyhd3eb1b0_0     non_existent             non_existent
# 540              pyhd3eb1b0_0     non_existent             non_existent
# 138              pyhd8ed1ab_1     non_existent             non_existent
# 682              non_existent           1.2.11               hd590300_1
# 605           py311haa95532_0     non_existent             non_existent
# 281         py311hfc23b7f_100     non_existent             non_existent
# 472           py311haa95532_0     non_existent             non_existent
# 77            py311haa95532_0     non_existent             non_existent
# 402           py311haa95532_0     non_existent             non_existent
# 516           py311haa95532_0     non_existent             non_existent
# 121           py311haa95532_0     non_existent             non_existent
# 304           py311h1ea47a8_7     non_existent             non_existent
# 463           py311haa95532_0     non_existent             non_existent
# 423                hd77b12b_0     non_existent             non_existent
# 671              pyhd3eb1b0_0     non_existent             non_existent
# 269              pyhd3eb1b0_0     non_existent             non_existent
# 228              pyhd3eb1b0_0     non_existent             non_existent
# 277           py311h2bbff1b_0     non_existent             non_existent
# 248           py311haa95532_1     non_existent             non_existent
# 254            h57928b3_5_cpu     non_existent             non_existent
# 271           py311haa95532_0     non_existent             non_existent
# 60            py311hd7041d2_0     non_existent             non_existent
# 686              pyhd3eb1b0_0            2.4.1             pyhd8ed1ab_0
# 595           py311haa95532_0     non_existent             non_existent
# 703              pyhd8ed1ab_0     non_existent             non_existent
# 496                      py_0     non_existent             non_existent
# 631              non_existent            2.5.1               h166bdaf_1
# 525           py311haa95532_0     non_existent             non_existent
# 194                      py_0     non_existent             non_existent
# 198              pyhd3eb1b0_1     non_existent             non_existent
# 67                 hd571b1d_2     non_existent             non_existent
# 324                hd5965a7_2     non_existent             non_existent
# 123                hcfcfb64_0     non_existent             non_existent
# 136                hd5965a7_3     non_existent             non_existent
# 430                hef061cf_2     non_existent             non_existent
# 342                h064cb6d_2     non_existent             non_existent
# 72                 ha16e049_0     non_existent             non_existent
# 470                h37bb463_0     non_existent             non_existent
# 140                h263813f_4     non_existent             non_existent
# 298                hd5965a7_2     non_existent             non_existent
# 543                hd5965a7_2     non_existent             non_existent
# 151                h84553ab_2     non_existent             non_existent
# 61                h45a597c_24     non_existent             non_existent
# 457           py311haa95532_0     non_existent             non_existent
# 331              pyhd3eb1b0_0     non_existent             non_existent
# 223              pyhd3eb1b0_0     non_existent             non_existent
# 0                pyhd3eb1b0_1     non_existent             non_existent
# 695                      py_1     non_existent             non_existent
# 339              pyhd8ed1ab_0     non_existent             non_existent
# 435           py311h2bbff1b_1     non_existent             non_existent
# 663           py311haa95532_0     non_existent             non_existent
# 86               pyhd3eb1b0_1     non_existent             non_existent
# 222           py311haa95532_0     non_existent             non_existent
# 231              pyhd3eb1b0_0     non_existent             non_existent
# 624              pyh95a074a_2     non_existent             non_existent
# 262           py311haa95532_0     non_existent             non_existent
# 552                h6c2663c_0     non_existent             non_existent
# 600           py311h746a85d_0     non_existent             non_existent
# 226           py311haa95532_0     non_existent             non_existent
# 433                h59b6b97_2     non_existent             non_existent
# 79            py311haa95532_0     non_existent             non_existent
# 249           py311hd7041d2_0     non_existent             non_existent
# 370                h2bbff1b_7            1.1.0               hd590300_1
# 334                h2bbff1b_7            1.1.0               hd590300_1
# 80            py311hd77b12b_7     non_existent             non_existent
# 62                 he774522_0            1.0.8               hd590300_5
# 664                h2bbff1b_0           1.28.1               hd590300_0
# 547                h2f4ed9d_0     non_existent             non_existent
# 494                haa95532_0         2024.2.2               hbcca054_0
# 667              non_existent            1.5.2               hd8ed1ab_1
# 702              non_existent            1.5.2             pyha770c72_1
# 208              pyhd3eb1b0_0     non_existent             non_existent
# 286              non_existent           1.18.0               h3faef2a_0
# 70            py311h2bbff1b_0     non_existent             non_existent
# ...
# 327           py311h2bbff1b_0     non_existent             non_existent
# 446              pyhd3eb1b0_0     non_existent             non_existent
# 475           py311haa95532_0     non_existent             non_existent
# 177           py311he2ea4bf_1     non_existent             non_existent
# 649           py311h2bbff1b_1     non_existent             non_existent
# 272           py311haa95532_2     non_existent             non_existent
# 209           py311haa95532_2     non_existent             non_existent
# 458           py311haa95532_0     non_existent             non_existent
# 499           py311h2bbff1b_0     non_existent             non_existent
# 127           py311haa95532_0     non_existent             non_existent
# 145           py311haa95532_1           2.17.2             pyhd8ed1ab_0
# 576           py311haa95532_0     non_existent             non_existent
# 341           py311haa95532_0     non_existent             non_existent
# 586           py311haa95532_0     non_existent             non_existent
# 128              pyhd3eb1b0_0     non_existent             non_existent
# 252           py311h8cc25b3_0     non_existent             non_existent
# 670           py311hd77b12b_0     non_existent             non_existent
# 278           py311haa95532_0     non_existent             non_existent
# 90            py311haa95532_0            3.1.2             pyhd8ed1ab_0
# 41            py311hd77b12b_0           5.15.9          py310h04931ad_5
# 575           py311h2bbff1b_0          12.12.2          py310hc6cd4ac_5
# 625           py311hd77b12b_0     non_existent             non_existent
# 360           py311haa95532_0     non_existent             non_existent
# 184           py311h91a9f6a_0     non_existent             non_existent
# 577           py311haa95532_0     non_existent             non_existent
# 391                he1021f5_0          3.10.14       hd12c33a_0_cpython
# 42               pyhd3eb1b0_0            2.9.0             pyhd8ed1ab_0
# 613           py311haa95532_0     non_existent             non_existent
# 429           py311haa95532_0     non_existent             non_existent
# 307           py311haa95532_0     non_existent             non_existent
# 542              pyhd3eb1b0_1     non_existent             non_existent
# 7             py311hd77b12b_0     non_existent             non_existent
# 232           py311haa95532_0     non_existent             non_existent
# 24               pyhd3eb1b0_0     non_existent             non_existent
# 170           py311haa95532_0     non_existent             non_existent
# 637              pyhd3eb1b0_0     non_existent             non_existent
# 450           py311hd77b12b_0     non_existent             non_existent
# 495              pyhd3eb1b0_0           2024.1             pyhd8ed1ab_0
# 54                    2_cp311             3.10                  4_cp310
# 221           py311haa95532_0     non_existent             non_existent
# 118  py3.11_cuda12.1_cudnn8_0     non_existent             non_existent
# 534                hde6ce7c_5     non_existent             non_existent
# 614              pyhd8ed1ab_0     non_existent             non_existent
# 526                      cuda              1.0                      cpu
# 676           py311haa95532_0           2024.1             pyhd8ed1ab_0
# 692              pyhd8ed1ab_0     non_existent             non_existent
# 400           py311haa95532_0     non_existent             non_existent
# 363           py311hd7041d2_0     non_existent             non_existent
# 30            py311h2bbff1b_0     non_existent             non_existent
# 181        py311haa95532_1000     non_existent             non_existent
# 344           py311h5da7b33_0     non_existent             non_existent
# 175           py311h2bbff1b_0            6.0.1          py310h2372a71_1
# 266           py311hd77b12b_0           26.0.2          py310h6883aea_0
# 124              pyhd3eb1b0_0     non_existent             non_existent
# 480           py311haa95532_0     non_existent             non_existent
# 644               h19c9488_10           5.15.8              hc9dc06e_21
# 216                h5bd16bc_7     non_existent             non_existent
# 74            py311haa95532_0     non_existent             non_existent
# 603           py311haa95532_0     non_existent             non_existent
# 471           py311haa95532_0     non_existent             non_existent
# 212           py311haa95532_0     non_existent             non_existent
# 340           py311hc35859c_1     non_existent             non_existent
# 149           py311h7b31ff4_1     non_existent             non_existent
# 426           py311h1ea47a8_1     non_existent             non_existent
# 639           py311h1ea47a8_1     non_existent             non_existent
# 148                h63175ca_0       2023.09.01               h7f4b329_2
# 357              non_existent              8.2               h8228510_1
# 374           py311haa95532_0     non_existent             non_existent
# 419           py311h2bbff1b_0     non_existent             non_existent
# 514                hd77b12b_1     non_existent             non_existent
# 314                hd77b12b_1     non_existent             non_existent
# 438           py311haa95532_1           2.31.0                      pip
# 572              pyhd3eb1b0_0     non_existent             non_existent
# 609           py311haa95532_0     non_existent             non_existent
# 300           py311haa95532_0     non_existent             non_existent
# 101           py311haa95532_0     non_existent             non_existent
# 13            py311haa95532_0     non_existent             non_existent
# 47            py311haa95532_0     non_existent             non_existent
# 386           py311h062c2fa_0     non_existent             non_existent
# 562              pyhd8ed1ab_0     non_existent             non_existent
# 661           py311h2eaa2aa_0     non_existent             non_existent
# 691           py311h2bbff1b_0     non_existent             non_existent
# 64            py311h2bbff1b_0     non_existent             non_existent
# 629           py311haa95532_0     non_existent             non_existent
# 211           py311hb4ba03d_0     non_existent             non_existent
# 467           py311hd77b12b_1            1.4.2          py310h1fdf081_0
# 668           py311h0b4df5a_0           1.13.0          py310hb13e2d6_0
# 288           py311haa95532_0     non_existent             non_existent
# 27            py311haa95532_0           0.13.2               hd8ed1ab_0
# 310              non_existent           0.13.2             pyhd8ed1ab_0
# 491              pyhd3eb1b0_0     non_existent             non_existent
# 347           py311haa95532_0     non_existent             non_existent
# 501              pyhd3eb1b0_1     non_existent             non_existent
# 94            py311ha68e1ae_0     non_existent             non_existent
# 258           py311haa95532_0           69.5.1             pyhd8ed1ab_0
# 245           py311hd77b12b_0           6.7.12          py310hc6cd4ac_0
# 299              pyhd3eb1b0_1           1.16.0             pyh6c4a22f_0
# 322           py311haa95532_0     non_existent             non_existent
# 506              pyhd3eb1b0_0     non_existent             non_existent
# 557                h6c2663c_1     non_existent             non_existent
# 387           py311haa95532_0     non_existent             non_existent
# 502              pyhd3eb1b0_0     non_existent             non_existent
# 264              pyhd3eb1b0_0     non_existent             non_existent
# 133           py311haa95532_0     non_existent             non_existent
# 98            py311haa95532_0     non_existent             non_existent
# 290              pyhd3eb1b0_0     non_existent             non_existent
# 476              pyhd3eb1b0_0     non_existent             non_existent
# 527              pyhd3eb1b0_0     non_existent             non_existent
# 581              pyhd3eb1b0_0     non_existent             non_existent
# 215              pyhd3eb1b0_0     non_existent             non_existent
# 220              pyhd3eb1b0_0     non_existent             non_existent
# 440           py311haa95532_1     non_existent             non_existent
# 171           py311haa95532_0     non_existent             non_existent
# 454           py311h2bbff1b_0     non_existent             non_existent
# 468                h2bbff1b_0     non_existent             non_existent
# 326              pyhd3eb1b0_0            0.6.2             pyhd8ed1ab_0
# 623           py311hd7041d2_0           0.14.1          py310h1f7b6fc_0
# 144           py311haa95532_0     non_existent             non_existent
# 620           py311haa95532_0             1.12         pypyh9d50eac_103
# 345           py311haa95532_0     non_existent             non_existent
# 606                h59b6b97_0     non_existent             non_existent
# 388              pyhd3eb1b0_0     non_existent             non_existent
# 320           py311haa95532_0     non_existent             non_existent
# 21               non_existent           2.16.2             pyhd8ed1ab_0
# 282              non_existent            0.7.0          py310h75e40e8_1
# 40               pyhd8ed1ab_0     non_existent             non_existent
# 602           py311haa95532_0     non_existent             non_existent
# 33               pyhd3eb1b0_0     non_existent             non_existent
# 479              pyhd3eb1b0_0     non_existent             non_existent
# 578              pyh0d69192_0            3.4.0             pyhc1e730c_0
# 321              pyhd3eb1b0_0     non_existent             non_existent
# 608           py311haa95532_0     non_existent             non_existent
# 548           py311haa95532_0     non_existent             non_existent
# 92                 h2bbff1b_0           8.6.13       noxft_h4845f30_101
# 28               pyhd3eb1b0_0     non_existent             non_existent
# 622              pyhd3eb1b0_0           0.10.2             pyhd8ed1ab_0
# 96               non_existent            2.0.1             pyhd8ed1ab_0
# 567           py311haa95532_0     non_existent             non_existent
# 405           py311haa95532_0     non_existent             non_existent
# 45               non_existent            2.0.0                      pip
# 395              non_existent  0.2.0.dev230426                      pip
# 8                         pip     non_existent             non_existent
# 65               pyhd8ed1ab_0     non_existent             non_existent
# 486           py311h2bbff1b_0              6.4          py310h2372a71_0
# 99            py311h746a85d_0           4.66.2             pyhd8ed1ab_0
# 193           py311haa95532_0           5.14.3             pyhd8ed1ab_0
# 561              non_existent            2.0.0                      pip
# 134           py311haa95532_0     non_existent             non_existent
# 437           py311h59ca53f_1            0.6.3          py310h1f7b6fc_1
# 119           py311haa95532_0     non_existent             non_existent
# 146           py311h2bbff1b_0     non_existent             non_existent
# 570           py311haa95532_1     non_existent             non_existent
# 696           py311haa95532_1           4.11.0             pyha770c72_0
# 464                h04d1e81_0            2024a               h0c530f3_0
# 156           py311haa95532_1     non_existent             non_existent
# 46            py311haa95532_0     non_existent             non_existent
# 531                h57928b3_0     non_existent             non_existent
# 568           py311hd77b12b_0     non_existent             non_existent
# 308              non_existent           15.1.0          py310h2372a71_0
# 694              pyhd3eb1b0_0     non_existent             non_existent
# 180           py311haa95532_0            2.2.1                      pip
# 227                h2bbff1b_1     non_existent             non_existent
# 396              pyhd3eb1b0_0     non_existent             non_existent
# 268                h21ff451_1     non_existent             non_existent
# 120               h82b7239_18     non_existent             non_existent
# 105              pyhd8ed1ab_0     non_existent             non_existent
# 492               hcb4865c_18     non_existent             non_existent
# 443           py311haa95532_0     non_existent             non_existent
# 537           py311haa95532_0     non_existent             non_existent
# 521              pyhd3eb1b0_0           0.2.13             pyhd8ed1ab_0
# 43            py311haa95532_1     non_existent             non_existent
# 112           py311haa95532_4     non_existent             non_existent
# 287           py311haa95532_0            3.0.2             pyhd8ed1ab_0
# 436              non_existent              3.2                      pip
# 50            py311haa95532_0     non_existent             non_existent
# 323           py311haa95532_0           0.43.0             pyhd8ed1ab_1
# 289           py311haa95532_1     non_existent             non_existent
# 66            py311haa95532_0     non_existent             non_existent
# 192                         4     non_existent             non_existent
# 2             py311h2bbff1b_0     non_existent             non_existent
# 4             py311haa95532_0     non_existent             non_existent
# 185              non_existent            0.4.0               hd590300_1
# 73               non_existent            0.4.0               h8ee46fc_1
# 82               non_existent            0.4.0               h8ee46fc_1
# 338              non_existent            0.3.9               hd590300_1
# 409              non_existent            0.4.1               h8ee46fc_1
# 536              non_existent             2.41               hd590300_0
# 498           py311haa95532_0     non_existent             non_existent
# 125              non_existent            1.0.7            h7f98852_1002
# 196              non_existent            1.1.1               hd590300_0
# 657              non_existent            1.2.4               h7391055_0
# 351              non_existent            1.8.9               h8ee46fc_0
# 389              non_existent           1.0.11               hd590300_0
# 201              non_existent            1.1.3               h7f98852_0
# 51               non_existent            1.3.4               h0b41bf4_2
# 253              non_existent           0.9.11               hd590300_0
# 190              non_existent           0.11.1            h7f98852_1002
# 240              non_existent            7.3.0            h0b41bf4_1003
# 5                non_existent            2.3.1            h7f98852_1002
# 353              non_existent           7.0.31            h7f98852_1007
# 155           py311haa95532_1     non_existent             non_existent
# 493                h8cc25b3_0            5.2.6               h166bdaf_0
# 483                he774522_0            0.2.5               h7f98852_2
# 683                hd77b12b_0     non_existent             non_existent
# 414              pyhd3eb1b0_0     non_existent             non_existent
# 535           py311h2bbff1b_0     non_existent             non_existent
# 512                hd77b12b_0            4.3.5               h59595ed_1
# 503                hd77b12b_0     non_existent             non_existent
# 451           py311haa95532_0     non_existent             non_existent
# 49            py311haa95532_0           3.17.0             pyhd8ed1ab_0
# 241                hcfcfb64_5           1.2.13               hd590300_5
# 187                h2bbff1b_0     non_existent             non_existent
# 191           py311haa95532_1     non_existent             non_existent
# 469           py311h2bbff1b_0     non_existent             non_existent
# 398           py311h2bbff1b_0     non_existent             non_existent
# 473                hd43e919_0            1.5.5               hfc55251_0
